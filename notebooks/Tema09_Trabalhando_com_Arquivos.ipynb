# %% [markdown]
# # Trabalhando com Arquivos

# %%
https://pymbook.readthedocs.io/en/latest/file.html
# Out:
#   File "<ipython-input-1-6628d859323d>", line 1
#     https://pymbook.readthedocs.io/en/latest/file.html
#            ^
# SyntaxError: invalid syntax
