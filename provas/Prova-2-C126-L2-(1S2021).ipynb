# %% [markdown]
# # Prova #2 C126-L2 (1S2021)
#
# ### Instruções
#
# 1. Para cada um dos exercícios a seguir, faça o seguinte:
#     * Adicione comentários ao seu código explicando o que você fez.
#     * Caso o exercício involva a implementação de uma função:
#         + Coloque um comentário dizendo o que a função faz, use **docstrings**.
#         + Escolha nomes auto-explicativos para suas funções e parâmetros.
#
# 2. Quando você terminar a prova, vá ao menu do Jupyter ou Colab e selecione a opção para fazer download do notebook.
#     * Os notebooks tem extensão .ipynb.
#     * Este deve ser o arquivo que você irá entregar.
#     * No Jupyter vá até a opção **File** -> **Download as** -> **Notebook (.ipynb)**.
#     * No Colab vá até a opção **File** -> **Download .ipynb**.
#
# 3. Em seguida, faça a entrega do notebook da prova (ou seja, anexe o arquivo) na tarefa criada no MS Teams.
# 4. Atente-se ao prazo de entrega definido na tarefa do MS Teams.
# 5. **A prova deve ser resolvida individualmente**.
# 6. Todas as questões têm o mesmo peso.
# 7. Não se esqueça de colocar seu nome e número de matrícula nos campos abaixo.
# 8. Você pode consultar o material de aula.
# 9. A interpretação faz parte da prova.
# 10. Boa sorte!

# %% [markdown]
# **Nome**:
#
# **Matrícula**:

# %% [markdown]
# ## Exercícios

# %% [markdown]
# #### 1) Exercício sobre listas e dicionários.
#
# Escreva uma função chamada `imprimirMaioresPreços` que receba uma **lista** contendo informações sobre preços de diversos produtos em diferentes datas e que retorne um **dicionário**, onde a **chave** de cada elemento é o nome (i.e., string) do produto e o **valor** associado é o **maior** preço que aquele produto já teve. Para testar a sua função, utilizaremos os valores abaixo como entrada. Veja que a lista com as informações dos produtos já está disponibilizada no código de teste, portanto, apenas implemente a função e execute o código de teste.
#
# |    Data    |  Produto  | Preço |
# |:----------:|:---------:|:-----:|
# | 29/06/2017 |   cebola  |  2.19 |
# | 29/06/2017 |   batata  |  1.98 |
# | 29/06/2017 |   alface  |  1.88 |
# | 22/06/2017 | beterraba |  2.48 |
# | 22/06/2017 |   alface  |  2.00 |
# | 22/06/2017 |   cebola  |  2.03 |
# | 15/06/2017 | beterraba |  2.44 |
# | 15/06/2017 |   alface  |  1.75 |
# | 15/06/2017 |   batata  |  2.11 |
#
# **IMPORTANTE**
# + Sua função deve ser o mais genérica possível, ou seja, ela deve funcionar até para podutos que não estão na tabela acima.

# %%
# Implemente aqui o código da função.

# %% [markdown]
# Teste sua implementação com o código abaixo, o qual deve resultar em todos os testes tendo o status OK.
#
# **NÃO ALTERE O CÓDIGO ABAIXO EM HIPÓTESE ALGUMA.**

# %%
lista = ['29/06/2020', 'cebola', 2.19, '29/06/2020', 'batata', 1.98, '29/06/2020', 'alface', 1.88, '22/06/2020', 'beterraba', 2.48, '22/06/2020', 'alface', 2.00, '22/06/2020', 'cebola', 2.03, '15/06/2020', 'beterraba', 2.44, '15/06/2020', 'alface', 1.75, '15/06/2020', 'batata', 2.11]

ret = 0

maioresPreços = imprimirMaioresPreços(lista)
if(maioresPreços == {'cebola': 2.19, 'batata': 2.11, 'alface': 2.0, 'beterraba': 2.48}):
    ret += 1

lista = ['01/01/2021', 'morango', 3.21, '29/06/2020', 'cebola', 2.19, '29/06/2020', 'batata', 1.98, '29/06/2020', 'alface', 1.88, '22/06/2020', 'beterraba', 2.48, '22/06/2020', 'alface', 2.00, '22/06/2020', 'cebola', 2.03, '15/06/2020', 'beterraba', 2.44, '15/06/2020', 'alface', 1.75, '15/06/2020', 'batata', 2.11]

maioresPreços = imprimirMaioresPreços(lista)
if(maioresPreços == {'morango': 3.21, 'cebola': 2.19, 'batata': 2.11, 'alface': 2.0, 'beterraba': 2.48}):
    ret += 1
    
if(ret == 2):
    print('Sua implementação está OK!')
else:
    print('Sua implementação não está correta...')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6f7ed363d3b7> in <module>
#       3 ret = 0
#       4
# ----> 5 maioresPreços = imprimirMaioresPreços(lista)
#       6 if(maioresPreços == {'cebola': 2.19, 'batata': 2.11, 'alface': 2.0, 'beterraba': 2.48}):
#       7     ret += 1
#
# NameError: name 'imprimirMaioresPreços' is not defined

# %% [markdown]
# #### 2) Exercício sobre POO.
#
# Implemente a classe mostrada no diagrama UML mostrado abaixo. Siga examente as especificações mostradas na figura, ou seja, nomes dos atributos, nomes dos métodos, número de parâmetros dos métodos, encapsulamentos dos membros da classe. etc.
#
# Seguem algumas instruções para a implementação da classe:
# 1. Os métodos `getMarca()`, `getModelo()`, `getPlaca()` e `getCor()` devem retornar os valores dos respectivos atributos.
# 2. O método **privado** `injetarCombustível()` deve retornar a string `injetando combustível`.
# 3. O método **privado** `acionarPastilhaDeFreio()` deve retornar a string `acionando pastilha de freio`.
# 4. O método **público** `acelerar()` deve chamar o método `injetarCombustível()` e em seguida retornar a string `Acelerando`.
# 5. O método **público** `frear()` deve chamar o método `acionarPastilhaDeFreio()` e em seguida retornar a string `Freando`.
# 6. O método **público** `imprimirInfo()` deve **imprimir** as informações do veículo, ou seja, sua marca, modelo, cor, placa e kilometragem.
# 7. O método **público** `setPlaca()` deve alterar o atributo **privado** `placa` com uma nova placa passada como agumento de entrada para o método.
#
# <img src="../figures/veiculoProva2.png" width="300" height="300">

# %%
# Implemente aqui a classe.

# %% [markdown]
# Teste sua implementação com o código abaixo, o qual deve resultar em todos os testes tendo o status OK.
#
# **NÃO ALTERE O CÓDIGO ABAIXO EM HIPÓTESE ALGUMA.**

# %%
carro = Veículo('VW', 'fusca', 'preto', 'FGT-3056', 100000)
ret = 0
if(carro.getMarca()=='VW'):
    ret += 1
if(carro.getModelo()=='fusca'):
    ret += 1
if(carro.getPlaca()=='FGT-3056'):
    ret += 1
if(carro.getCor()=='preto'):
    ret += 1
if(carro.kilometragem==100000):
    ret += 1
if(carro._cor=='preto'):
    ret += 1
try:
    carro.__marca
except AttributeError:
    ret += 1
try:
    carro.__modelo
except AttributeError:
    ret += 1
try:
    carro.__placa
except AttributeError:
    ret += 1
try: 
    carro.__injetarCombustível()
except AttributeError:
    ret += 1
try:
    carro.__acionarPastilhaDeFreio()
except AttributeError:
    ret += 1
carro.setPlaca('FST-6789')
if(carro.getPlaca()=='FST-6789'):
    ret += 1
if(carro.imprimirInfo()==None):
    ret += 1
if(carro.frear()=='Freando'):
    ret += 1
if(carro.acelerar()=='Acelerando'):
    ret += 1
if(ret==15):
    print('\nSua implementação está OK!')
else:
    print('\nSua implementação NÃO está correta...')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-893a1fbac3b0> in <module>
# ----> 1 carro = Veículo('VW', 'fusca', 'preto', 'FGT-3056', 100000)
#       2 ret = 0
#       3 if(carro.getMarca()=='VW'):
#       4     ret += 1
#       5 if(carro.getModelo()=='fusca'):
#
# NameError: name 'Veículo' is not defined

# %% [markdown]
# #### 3)  Exercício sobre arquivos alfanuméricos (arquivos de texto).
#
# Escreva uma função chamada `calcularMédia()` que receba como parâmetro de entrada o nome de um arquivo. Esta função deve ler o arquivo, o qual será um arquivo contendo ao menos 1 número real por linha e, para cada linha, a função deve calcular a média destes valores e adicioná-lo a uma lista. Desta forma, cada elemento da lista será a média de cada uma das linhas do arquivo.
#
# **DICAS**
# 1. Após ler uma linha do arquivo, use o método `split()` da classe string para obter uma lista onde cada elemento é um dos valores da linha.
# 2. Use a função embutida `float()` para converter a string representando cada um dos valores da lista em um número em ponto flutuante.

# %%
# Implemente aqui o código da função.

# %% [markdown]
# Teste sua implementação com o código abaixo, o qual deve resultar em todos os testes tendo o status OK.
#
# **NÃO ALTERE O CÓDIGO ABAIXO EM HIPÓTESE ALGUMA.**

# %%
with open('numeros.txt', 'w') as f:
    f.write('5 4 3 2 1\n')
    f.write('4 4\n')
    f.write('2.7\n')
    f.write('3.14 2.1 1.7')

ret = 0
if(calcularMédia('numeros.txt') == [3.0, 4.0, 2.7, 2.3133333333333335]):
    ret += 1
    
if(ret == 1):
    print('Sua implementação está OK!')
else:
    print('Sua implementação não está correta...')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bd2f3448fcf7> in <module>
#       6
#       7 ret = 0
# ----> 8 if(calcularMédia('numeros.txt') == [3.0, 4.0, 2.7, 2.3133333333333335]):
#       9     ret += 1
#      10
#
# NameError: name 'calcularMédia' is not defined

# %% [markdown]
# #### 4) Exercício sobre programação orientada a objetos e manipulação de arquivos.
#
# Neste exercício você deve implementar a classe do diagrama abaixo e seguir as dicas para sua implementação.
#
# **IMPORTANTE**: Neste exercício você deverá utilizar um **arquivo CSV** para armazenar as informações sobre os animais de um Zoológico.
#
# <img src="../figures/zoologicoCSVProva2.png" width="300" height="300">
#
# Seguem algumas dicas para a implementação da classe:
#
# 1. Prestem bastante atenção ao tipo de acesso (i.e., privado, protegido ou público) de cada **atributo** e **método** da classe.
# 2. Usem a instrução `with` para trabalhar com os arquivos. Lembrem-se que a instrução `with` fecha o arquivo automaticamente.
# 3. O construtor da classe `Zoológico` deve criar um **arquivo CSV** chamado `zoologico.csv` com as seguintes colunas: `Registro`, `Nome`, `Pernas`, `Idade` e `Peso`. Este arquivo será usado para armazenar as informações de cada animal do zoológico.
# 4. O atributo `nome` da classe `Zoológico` é o nome do zoológico.
# 5. O método `adicionarAnimal(animal)` da classe `Zoológico` deve adicionar um novo animal ao arquivo `zoologico.csv` apenas se a `capacidade` do zoológico não tiver sido atingida e o registro do animal não estiver presente no arquivo, nesse caso, o método deve retornar `True`. Caso contrário, se o zoológico estiver cheio ou o registro do animal já estiver presente no arquivo, o método deve retornar `False`.
# 6. O parâmetro de entrada `animal` do método `adicionarAnimal` é uma lista com valores para os seguintes elementos: `registro`, `nome`, `pernas`, `idade` e `peso` de cada animal a ser adicionado ao arquivo.
# 7. O método `removerAnimal(registro)` da classe `Zoológico` deve remover um animal do arquivo `zoologico.csv` e retornar `True` após a remoção bem sucedida do animal. Caso contrário, se o animal não existir no arquivo, então o método deve retornar `False`.
#
#     **DICAS**:
#     + Antes de remover o animal, verifique se ele está presente no arquivo `zoologico.csv`.
#     + Uma forma simples de remover um animal do arquivo é criar uma lista onde cada um dos elementos é uma das linhas do arquivo exceto aquela do animal a ser removido, abrir o arquivo `zoologico.csv` com o modo de operação `w` para que todas as informações anteriores sejam apagadas e, em seguida, escrever cada uma das linhas da lista no arquivo.
#
# 8. O método `listarAnimais()` da classe `Zoológico` deve imprimir as informações de todos os animais do zoológico. Este método deve retornar `True` caso a ocupação atual do zoológico seja maior do que 0. Caso contrário, se o zoológico estiver vazio e nenhuma informação for impressa, o método deve retornar `False`.
# 9. O método `getOcupaçãoAtual()` da classe `Zoológico` deve retornar o número de animais do zoológico.
# 10. O método `listarAnimal(registro)` da classe `Zoológico` deve imprimir as informações do animal com o `registro` passado como argumento de entrada para o método. Este método deve retornar `True` caso a ocupação atual do zoológico seja maior do que 0 e se o animal estiver presente no arquivo `zoologico.csv`. Caso contrário, se o zoológico estiver vazio ou o animal não estiver presente no arquivo, então, nenhuma informação deve ser impressa e o método deve retornar `False`.

# %%
# Implemente o código do exercício aqui.

# %% [markdown]
# Teste sua implementação com o código abaixo, o qual deve resultar em todos os testes tendo o status OK.
#
# **NÃO ALTERE O CÓDIGO ABAIXO EM HIPÓTESE ALGUMA.**

# %%
import csv

# Definindo alguns animais.
animal1 = ['101', 'Arara Azul', '2', '95', '2.0']
animal2 = ['678', 'Elefante', '4', '54', '500.31']
animal3 = ['123', 'Jararaca', '0', '1', '0.1']
animal4 = ['456', 'Crocodilo', '0', '3', '30.67']

# Contador de casos de sucesso.
sucesso = 0 
falha = 0

# Instanciando um zoológico.
zoo = Zoológico('Central', 3)

if zoo.getOcupaçãoAtual() == 0:
    print('Teste 1 - Ocupação inicial está OK.')
    sucesso += 1
else:
    print('Teste 1 - Ocupação inicial NÃO está OK.')
    falha += 1
    
# Listando os animais do zoológico.
if zoo.listarAnimais() == False:
    print('Teste 2 - Listagem de animais está OK.')
    sucesso += 1
else:
    print('Teste 2 - Listagem de animais NÃO está OK.')
    falha += 1
    
# Adicionando animal.
if zoo.adicionarAnimal(animal1) == True:
    print('Teste 3 - Adiçao de animal está OK.')
    sucesso += 1
else:
    print('Teste 3 - Adiçao de animal NÃO está OK.')
    falha += 1

# Verificando a ocupação atual.
if zoo.getOcupaçãoAtual() == 1:
    print('Teste 4 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 4 - Ocupação atual NÃO está OK.')
    falha += 1

# Listando os animais do zoológico.
if zoo.listarAnimais() == True:
    print('Teste 5 - Listagem de animais está OK.')
    sucesso += 1
else:
    print('Teste 5 - Listagem de animais NÃO está OK.')
    falha += 1
    
if zoo.adicionarAnimal(animal2) == True:
    print('Teste 6 - Adiçao de animal está OK.')
    sucesso += 1
else:
    print('Teste 6 - Adiçao de animal NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if zoo.getOcupaçãoAtual() == 2:
    print('Teste 7 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 7 - Ocupação atual NÃO está OK.')
    falha += 1

# Adicionando animal.
if zoo.adicionarAnimal(animal3) == True:
    print('Teste 8 - Adiçao de animal está OK.')
    sucesso += 1
else:
    print('Teste 8 - Adiçao de animal NÃO está OK.')
    falha += 1

# Verificando a ocupação atual.
if zoo.getOcupaçãoAtual() == 3:
    print('Teste 9 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 9 - Ocupação atual NÃO está OK.')
    falha += 1

# Adicionando animal.
if zoo.adicionarAnimal(animal4) == False:
    print('Teste 10 - Adiçao de animal está OK.')
    sucesso += 1
else:
    print('Teste 10 - Adiçao de animal NÃO está OK.')
    falha += 1
    
# Listando os animais.
if zoo.listarAnimais() == True:
    print('Teste 11 - Listagem de animais está OK.')
    sucesso += 1
else:
    print('Teste 11 - Listagem de animais NÃO está OK.')
    falha += 1

# Removendo um animal.
if zoo.removerAnimal('456') == False:
    print('Teste 12 - Remoção de animal está OK.')
    sucesso += 1
else:
    print('Teste 12 - Remoção de animal NÃO está OK.')
    falha += 1
    
# Removendo um animal.
if zoo.removerAnimal('789') == False:
    print('Teste 13 - Remoção de animal está OK.')
    sucesso += 1
else:
    print('Teste 13 - Remoção de animal NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if zoo.getOcupaçãoAtual() == 3:
    print('Teste 14 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 14 - Ocupação atual NÃO está OK.')
    falha += 1
    
# Removendo animal.
if zoo.removerAnimal('101') == True:
    print('Teste 15 - Remoção de animal está OK.')
    sucesso += 1
else:
    print('Teste 15 - Remoção de animal NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if zoo.getOcupaçãoAtual() == 2:
    print('Teste 16 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 16 - Ocupação atual NÃO está OK.')
    falha += 1
    
# Removendo animal.
if zoo.removerAnimal('678') == True:
    print('Teste 17 - Remoção de animal está OK.')
    sucesso += 1
else:
    print('Teste 17 - Remoção de animal NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if zoo.getOcupaçãoAtual() == 1:
    print('Teste 18 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 18 - Ocupação atual NÃO está OK.')
    falha += 1

# Removendo animal.
if zoo.removerAnimal('123') == True:
    print('Teste 19 - Remoção de animal está OK.')
    sucesso += 1
else:
    print('Teste 19 - Remoção de animal NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if zoo.getOcupaçãoAtual() == 0:
    print('Teste 20 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 20 - Ocupação atual NÃO está OK.')
    falha += 1

# Removendo animal.
if zoo.removerAnimal('120') == False:
    print('Teste 21 - Remoção de animal está OK.')
    sucesso += 1
else:
    print('Teste 21 - Remoção de animal NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if zoo.getOcupaçãoAtual() == 0:
    print('Teste 22 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 22 - Ocupação atual NÃO está OK.')
    falha += 1
    
# Listando os animais.
if zoo.listarAnimais() == False:
    print('Teste 23 - Listagem de animais está OK.')
    sucesso += 1
else:
    print('Teste 23 - Listagem de animais NÃO está OK.')
    falha += 1
    
# Adicionando um animal.
if zoo.adicionarAnimal(animal1) == True:
    print('Teste 24 - Adiçao de animal está OK.')
    sucesso += 1
else:
    print('Teste 24 - Adiçao de animal NÃO está OK.')
    falha += 1
    
# Adicionando animal.
if zoo.adicionarAnimal(animal1) == False:
    print('Teste 25 - Adiçao de animal está OK.')
    sucesso += 1
else:
    print('Teste 25 - Adiçao de animal NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if zoo.getOcupaçãoAtual() == 1:
    print('Teste 26 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 26 - Ocupação atual NÃO está OK.')
    falha += 1
    
# Busca por animal específico.
if zoo.listarAnimal('333') == False:
    print('Teste 27 - Busca por animal específico está OK.')
    sucesso += 1
else:
    print('Teste 27 - Busca por animal específico NÃO está OK.')
    falha += 1
    
# Busca por animal específico.
if zoo.listarAnimal('101') == True:
    print('Teste 28 - Busca por animal específico está OK.')
    sucesso += 1
else:
    print('Teste 28 - Busca por animal específico NÃO está OK.')
    falha += 1
    
# Removendo animal.
if zoo.removerAnimal('101') == True:
    print('Teste 29 - Remoção de animal está OK.')
    sucesso += 1
else:
    print('Teste 29 - Remoção de animal NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if zoo.getOcupaçãoAtual() == 0:
    print('Teste 30 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 30 - Ocupação atual NÃO está OK.')
    falha += 1

print('\n\n******* Resultado final dos testes *******')
if sucesso == 30 and falha == 0:
    print('Sucessos: %d - Falhas: %d' % (sucesso, falha))
    print('Todos os testes foram bem sucedidos, sua implementação está OK!')
else:
    print('Sucessos: %d - Falhas: %d' % (sucesso, falha))
    print('Alguns testes falharam, sua implementação NÃO está OK... verifique seu código.')
print('******************************************')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-57ef556df71b> in <module>
#      12
#      13 # Instanciando um zoológico.
# ---> 14 zoo = Zoológico('Central', 3)
#      15
#      16 if zoo.getOcupaçãoAtual() == 0:
#
# NameError: name 'Zoológico' is not defined
