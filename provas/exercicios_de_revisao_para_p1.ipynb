# %% [markdown]
# # Exercícios de revisão para a prova #1
#
# ### Instruções:
#
# 1. Para cada um dos exercícios a seguir, faça o seguinte:
#     * Adicione comentários ao seu código explicando o que você fez.
#     * Caso o exercício involva a implementação de uma função:
#         + Coloque um comentário dizendo o que a função faz, use **docstrings**.
#         + Escolha nomes auto-explicativos para suas funções e parâmetros.
# 2. Quando você terminar os exercícios, vá ao menu do Jupyter ou Colab e selecione a opção para fazer download do notebook.
#     * Os notebooks tem extensão .ipynb.
#     * Este deve ser o arquivo que você irá entregar.
#     * No Jupyter vá até a opção **File** -> **Download as** -> **Notebook (.ipynb)**.
#     * No Colab vá até a opção **File** -> **Download .ipynb**.
#
# 3. Em seguida, faça a entrega do notebook (ou seja, anexe o arquivo) na tarefa criada no MS Teams.
# 4. Atente-se ao prazo de entrega definido na tarefa do MS Teams.
# 5. Não se esqueça de colocar seu nome e número de matrícula nos campos abaixo.

# %% [markdown]
# **Nome**:
#
# **Matrícula**:

# %% [markdown]
# #### 1) Exercício sobre laços de repetição, operadores e funções.
#
# Dizemos que um número inteiro positivo é triangular se ele é o produto de três números inteiros consecutivos. Por exemplo, 120 é triangular, pois 4 * 5 * 6 = 120. Crie uma função chamada de `éNúmeroTriangular` que dado um número inteiro positivo `n`, verifique se `n` é triangular ou não. Sua função deve retornar uma string informando se o número é triangular ou não, por exemplo, para `n=120`, a função deve retornar `120 é o produto de 4*5*6` e caso `n` não seja triangular, como por exemplo  o numero `73`, então sua função deve retornar `73 nao é triangular`. Teste a função com os seguntes exemplos:
#
# ```python
# isTringularNumber(73)
# isTringularNumber(120)
# isTringularNumber(1024)
# isTringularNumber(720)
# ```
#
# O resultado esperado para a execução das chamadas acima é
#
# ```python
# 73 nao é triangular
# 120 é o produto 4*5*6
# 1024 nao é triangular
# 720 é o produto 8*9*10
# ```

# %%
# Implemente aqui o código da função.

# %% [markdown]
# Após executar o código abaixo, você deve ter o resultado esperado mostrado acima.

# %%
print('Resultado:', éNúmeroTriangular(73), ' - Resultado correto?', éNúmeroTriangular(73)=='73 nao é triangular')
print('Resultado:', éNúmeroTriangular(120), ' - Resultado correto?', éNúmeroTriangular(120)=='120 é o produto de 4*5*6')
print('Resultado:', éNúmeroTriangular(1024), ' - Resultado correto?', éNúmeroTriangular(1024)=='1024 nao é triangular')
print('Resultado:', éNúmeroTriangular(720), ' - Resultado correto?', éNúmeroTriangular(720)=='720 é o produto de 8*9*10')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9a5962886d0f> in <module>
# ----> 1 print('Resultado:', éNúmeroTriangular(73), ' - Resultado correto?', éNúmeroTriangular(73)=='73 nao é triangular')
#       2 print('Resultado:', éNúmeroTriangular(120), ' - Resultado correto?', éNúmeroTriangular(120)=='120 é o produto de 4*5*6')
#       3 print('Resultado:', éNúmeroTriangular(1024), ' - Resultado correto?', éNúmeroTriangular(1024)=='1024 nao é triangular')
#       4 print('Resultado:', éNúmeroTriangular(720), ' - Resultado correto?', éNúmeroTriangular(720)=='720 é o produto de 8*9*10')
#
# NameError: name 'éNúmeroTriangular' is not defined

# %% [markdown]
# #### 2) Exercício sobre laços de repetição, operadores e funções.
#
# Implemente uma função chamada `éPrimo` que recebe um número inteiro `n` maior do que 0 e devolve `True` se `n` é um número primo e devolve `False` caso contrário.
#
# **OBS.**: É importante lembrar que um número inteiro é primo se ele é maior do que 1 e seus únicos divisores são ele mesmo e 1. Assim, 1 não é primo.
#
# Teste a função com os seguntes exemplos:
#
# ```python
# print('1 é primo?', primo(1))
# print('2 é primo?', primo(2))
# print('3 é primo?', primo(3))
# print('4 é primo?', primo(4))
# ```
#
# O resultado esperado para a execução dos comandos acima é
#
# ```python
# 1 é primo? False
# 2 é primo? True
# 3 é primo? True
# 4 é primo? False
# ```

# %%
# Implemente aqui o código da função.

# %% [markdown]
# Após executar o código abaixo, você deve ter o resultado esperado mostrado acima.

# %%
print('1 é primo?', éPrimo(1), ' - Resultado correto?', éPrimo(1)==False)
print('2 é primo?', éPrimo(2), ' - Resultado correto?', éPrimo(2)==True)
print('3 é primo?', éPrimo(3), ' - Resultado correto?', éPrimo(3)==True)
print('4 é primo?', éPrimo(4), ' - Resultado correto?', éPrimo(4)==False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-07afb7e65ef5> in <module>
# ----> 1 print('1 é primo?', éPrimo(1), ' - Resultado correto?', éPrimo(1)==False)
#       2 print('2 é primo?', éPrimo(2), ' - Resultado correto?', éPrimo(2)==True)
#       3 print('3 é primo?', éPrimo(3), ' - Resultado correto?', éPrimo(3)==True)
#       4 print('4 é primo?', éPrimo(4), ' - Resultado correto?', éPrimo(4)==False)
#
# NameError: name 'éPrimo' is not defined

# %% [markdown]
# #### 3) Exercício sobre laços de repetição, operadores e funções.
#
# Dado um número natural na base binária, crie uma função chamada `converteBinParaDec` para transformá-lo para a base decimal.
#
# **Exemplo de como realizar a conversão**:
#
# Dado o valor bináio `10010`, a saída será `18`, que o valor decimal correspondente, pois $1 \times 2^4 + 0 \times 2^3 + 0 \times 2^2 + 1 \times 2^1 + 0 \times 2^0 = 18$.

# %%
# Implemente aqui o código da função.

# %% [markdown]
# Teste sua função com os exemplos abaixo.

# %%
binVal = 10010
print("Número binário", binVal, "em decimal é", converteBinParaDec(binVal), ' - Correto?', converteBinParaDec(binVal)==18)

binVal = 111010
print("Número binário", binVal, "em decimal é", converteBinParaDec(binVal), ' - Correto?', converteBinParaDec(binVal)==58)

binVal = 111
print("Número binário", binVal, "em decimal é", converteBinParaDec(binVal), ' - Correto?', converteBinParaDec(binVal)==7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2769f69da430> in <module>
#       1 binVal = 10010
# ----> 2 print("Número binário", binVal, "em decimal é", converteBinParaDec(binVal), ' - Correto?', converteBinParaDec(binVal)==18)
#       3
#       4 binVal = 111010
#       5 print("Número binário", binVal, "em decimal é", converteBinParaDec(binVal), ' - Correto?', converteBinParaDec(binVal)==58)
#
# NameError: name 'converteBinParaDec' is not defined

# %% [markdown]
# #### 4) Exercício sobre recursão.
#
# Escreva uma função recursiva, chamada de `somaRecursiva`, que calcule a soma de todos os números de `1` a `n`, onde `n` é o parâmetro de entrada da função.

# %%
# Implemente o código do exercício aqui.

# %% [markdown]
# Execute o trecho de código abaixo para testar sua função.
#
# Se a sua função estiver correta, então a seguinte frase será impressa: `Implementação da função está correta!`, caso contrário, a seguinte frase será impressa: `Implementação da função NÃO está correta!`

# %%
resultados_corretos = [1, 3, 6, 10, 15, 21]

for n in range(0, len(resultados_corretos)):
    ret = True
    if somaRecursiva(n+1) != resultados_corretos[n]:
        ret = False
        break

if(ret==True):
    print('Sua implementação está correta!')
else:
    print('Sua implementação NÃO está correta!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-fd469b184c65> in <module>
#       3 for n in range(0, len(resultados_corretos)):
#       4     ret = True
# ----> 5     if somaRecursiva(n+1) != resultados_corretos[n]:
#       6         ret = False
#       7         break
#
# NameError: name 'somaRecursiva' is not defined

# %% [markdown]
# #### 5) Exercício sobre laços de repetição, operadores e funções.
#
# Implemente uma função chamada `converteDecParaBin` que converta um número decimal em um número binário. Por exemplo, o número decimal `18` quando convertido em binário é representado como `10010`. O número binário deve ser representado como um número inteiro (tipo `int`), ou seja, sua função `converteDecParaBin` deve retornar um número inteiro que é a representação do valor binário.
#
# Para converter o número decimal em binário, siga os seguintes passos:
# 1. Divida o número por 2.
# 2. Obtenha o quociente **inteiro** da divisão por 2, o qual será usado na próxima iteração.
# 3. Obtenha o **resto** da divisão por 2, o qual será o dígito binário.
# 4. Multiplique o **resto** da divisão pela posição do dígito binário quando representado como um número decimal, ou seja, se o bit está na posição das unidades, multiplique seu valor por $10^0$, se o bit está na posição das dezenas, multiple seu valor por $10^1$ e assim por diante.
# 5. Acumule os valores resultantes da multiplicação do passo anterior (**Dica**: inicialize a variável de acumulação com 0).
# 6. Repita os passos anteriores até que o quociente seja igual a 0.
#
# Exemplo: convertendo o valor decimal `13` em binário
#
# | Divisão por 2 | Quociente | Resto | Bit # |  10**(Bit #) | Resto * 10**(Bit #) |     Acumulação    |
# |:-------------:|:---------:|:-----:|:-----:|:------------:|:-------------------:|:-----------------:|
# |      13/2     |     6     |   1   |   0   |   10**0 = 1  |      1 * 1 = 1      |     0 + 1 = 1     |
# |      6/2      |     3     |   0   |   1   |  10**1 = 10  |      0 * 10 = 0     |     1 + 0  = 1    |
# |      3/2      |     1     |   1   |   2   |  10**2 = 100 |       1 * 100       |   100 + 1 = 101   |
# |      1/2      |     0     |   1   |   3   | 10**3 = 1000 |       1 * 1000      | 1000 + 101 = 1101 |
#
#
# Utilizando os resultados da tabela acima podemos converter o número decimal `13` como:
#
# $$1*(10^0) = 1$$
# $$1 + 0*(10^1) = 1$$
# $$1 + 1*(10^2) = 101$$
# $$101 + 1*(10^3) = 1101$$
#
#
#
#
#
# Então, `13`= `1101`.

# %%
# Implemente o código do exercício aqui.

# %% [markdown]
# Execute o trecho de código abaixo para testar sua função.
#
# Se a sua função estiver correta, então a seguinte frase será impressa: `Implementação da função está correta!`, caso contrário, a seguinte frase será impressa: `Implementação da função NÃO está correta!`

# %%
entradas = [13, 7, 16, 734]
resultados_esperados = [1101, 111, 10000, 1011011110]

for i in range(0, len(entradas)):
    ret = True
    if converteDecParaBin(entradas[i]) != resultados_esperados[i]:
        ret = False
        break
        
if(ret==True):
    print('Sua implementação está correta!')
else:
    print('Sua implementação NÃO está correta!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-30a129ef1118> in <module>
#       4 for i in range(0, len(entradas)):
#       5     ret = True
# ----> 6     if converteDecParaBin(entradas[i]) != resultados_esperados[i]:
#       7         ret = False
#       8         break
#
# NameError: name 'converteDecParaBin' is not defined

# %% [markdown]
# #### 6) Exercício sobre números arbitrários de parâmetros de entrada passados para uma função.
#
# Crie uma função chamada `encontrarMenorNome()` que aceite um número qualquer (ou seja, arbitrário) de nomes de alunos de uma escola como parâmetros de entrada e retorne o menor nome de todos, bem como quantas letras possuem esse nome.
#
# **DICAS**:
#
# + Perceba que sua função deve retornar 2 valores, a string correspondente ao menor nome e a quantidade de caracteres naquela string.
# + Lembre-se que a função recebe do interpretador uma **tupla** com todos os parâmetros de entrada. Uma **tupla** é uma coleção de objetos que pode ser iterada com um laço de repetição `for`, por exemplo.
#
# **Exemplo:**
#
# ```python
# # definindo uma tupla.
# tupla = (0,1,2,3)
#
# # iterando através dos valores da tupla com um laço for.
# for valor in tupla:
#     print(valor)
# ```

# %%
# Implemente o código do exercício aqui.

# %% [markdown]
# Execute o trecho de código abaixo para testar sua função.
#
# **NÃO ALTERE O CÓDIGO ABAIXO EM HIPÓTESE ALGUMA. SUA IMPLEMENTAÇÃO DEVE FUNCIONAR COM O TRECHO DE CÓDIGO ABAIXO SEM NENHUMA ALTERAÇÃO.**

# %%
ret = 0

# TESTE #1
nome, tamanho = encontrarMenorNome('Maycol', 'Natália')
nome_esperado, tamanho_esperado = 'Maycol', 6

if nome == nome_esperado and tamanho == tamanho_esperado:
    ret += 1

# TESTE #2
nome, tamanho = encontrarMenorNome('Maycol', 'Felipe', 'Artur', 'Larissa')
nome_esperado, tamanho_esperado = 'Artur', 5

if nome == nome_esperado and tamanho == tamanho_esperado:
    ret += 1

# TESTE #3
nome, tamanho = encontrarMenorNome('Maycol', 'Felipe', 'Ana', 'Laura', 'Luana', 'Júlia')
nome_esperado, tamanho_esperado = 'Ana', 3

if nome == nome_esperado and tamanho == tamanho_esperado:
    ret += 1
    
if(ret == 3):
    print('Implementação da função está correta!')
else:
    print('Implementação da função NÃO está correta!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9d583a665a5d> in <module>
#       2
#       3 # TESTE #1
# ----> 4 nome, tamanho = encontrarMenorNome('Maycol', 'Natália')
#       5 nome_esperado, tamanho_esperado = 'Maycol', 6
#       6
#
# NameError: name 'encontrarMenorNome' is not defined
