# %% [markdown]
# # C126-L1 - Exercício sobre programação orientada a objetos

# %% [markdown]
# Implemente todas as classes do diagrama de classes abaixo e seus respectivos relacionamentos.
#
# <img src="../figures/estacionamento.png" width="600" height="600">
#
# Seguem algumas dicas para a implementação das classes:
#
# 1. Prestem bastante atenção ao tipo de acesso (i.e., privado, protegido ou público) de cada **atributo** e **método** de cada classe.
# 2. Não é necessário criar nenhum **atribuito** ou **método** novo para nenhuma das classes mostradas no diagrama acima. Use apenas os **atribuitos** e **métodos** que aparecem no diagrama de classes.
# 3. O método `getPlaca` da classe `Veículo` deve retornar a string correspondente à placa do veículo.
# 4. O método `imprimirInfo` da classe `Veículo` deve imprimir as seguintes informações de um objeto (**atributos**) `marca`, `modelo`, `cor`, `placa` e `kilometragem`.
# 5. Os métodos `acelerar()`, `frear()`, `injetarCombustível()` e `acionarPastilhaDeFreio()` da classe `Veículo` não tem nenhum valor de retorno, elas devem apenas imprimir uma mensagem dizendo o que elas fazem.
# 6. O atributo `veículos` da classe `Estacionamento` é um dicinário que irá armazenar os veículos estacionados no estacionamento com a placa do veículo sendo a chave de cada um dos elementos do dicionário.
# 7. O atributo `nome` da classe `Estacionamento` é o nome do estacionamento.
# 8. O método `adicionarVeículo(placa, veículo)` da classe `Estacionamento` deve adicionar um novo veículo ao dicionário `veículos` apenas se a `capacidade` do estacionamento não tiver sido atingida, nesse caso, o método deve retornar `True`. Caso contrário, se o estacionamento estiver cheio, o método deve retornar `False`.
# 9. O método `removerVeículo(placa)` da classe `Estacionamento` deve remover um veículo do dicionário `veículos` e retornar `True` após a remoção bem sucedida do veículo. Caso contrário, se o veículo não existir no dicionário `veículos`, então o método deve retornar `False`. (**DICA**: antes de remover o veículo, verifique se o veículo está presente no dicionário `veículos` utilizando o operador de associação `in`).
# 10. O método `listarVeículos()` da classe `Estacionamento` deve imprimir as informações de todos os veículos estacionados no estacionamento. Use o método `imprimirInfo()` da classe `Veículo` para imprimri as informações de cada veículo. O método `listarVeículos()` deve retornar `True` caso a ocupação atual do estacionamento seja maior do que 0. Caso contrário, se o estacionamento estiver vazio e nehuma informação for impressa, o método deve retornar `False`
# 11. O método `getOcupaçãoAtual()` da classe `Estacionamento` deve retornar o número de carros estacionados no estacionamento.

# %%
# Implemente o código do exercício aqui.

# %% [markdown]
# Teste sua implementação com o código abaixo. Execute o código abaixo o qual deve resultar em todos os testes tendo o status OK.
#
# **NÃO ALTERE O CÓDIGO ABAIXO EM HIPÓTESE ALGUMA. SUA IMPLEMENTAÇÃO DEVE FUNCIONAR COM O TRECHO DE CÓDIGO ABAIXO SEM NENHUMA ALTERAÇÃO.**

# %%
# Instanciando alguns veículos.
moto1 = Motocicleta('Honda', 'CB650R', 'vermelho', 'OOK2034', 31300.02)
onibus1 = Ônibus('Mercedes-Benz', 'Paradiso G7 1200', 'branco', 'OST8989', 200010.99)
carro1 = Carro('Fiat', 'Mobi', 'azul', 'HDT6542', 1000.34)
carro2 = Carro('Volvo', 'XC60', 'amarelo', 'HOT4356', 5100.33)

# Contador de casos de sucesso.
sucesso = 0 
falha = 0

# Verificando suas respecitvas kilometragens.
def verificaKilometragem(veiculos, valores_esperados):
    ret = True
    for i in range(0, len(veiculos)):
        if veiculos[i].kilometragem != valores_esperados[i]:
            ret = False
            break
    return ret

valores_esperados = [1000.34, 31300.02, 200010.99]
veiculos = [carro1, moto1, onibus1]
if(verificaKilometragem(veiculos, valores_esperados) == True):
    print('Teste 1 - Kilometragem está OK.')
    sucesso += 1
else:
    print('Teste 1 - Kilometragem NÃO está OK.')
    falha += 1

# Instanciando um estacionamento.
estacionamento = Estacionamento('Central', 3)

if estacionamento.getOcupaçãoAtual() == 0:
    print('Teste 2 - Ocupação inicial está OK.')
    sucesso += 1
else:
    print('Teste 2 - Ocupação inicial NÃO está OK.')
    falha += 1
    
# Testando o acesso a um atributo privado.
try:
    onibus1.__marca
    ret = False
except AttributeError:
    ret = True
    
if ret == True:
    print('Teste 3 - Acesso a atributo privado está OK.')
    sucesso += 1
else:
    print('Teste 3 - Acesso a atributo privado NÃO está OK.')
    falha += 1

try:
    marca = onibus1.marca
    ret = False
except AttributeError:
    ret = True

if ret == True:
    print('Teste 4 - Acesso a atributo inexistente está OK.')
    sucesso += 1
else:
    print('Teste 4 - Acesso a atributo inexistente NÃO está OK.')
    falha += 1
    
try:
    marca = onibus1._marca
    ret = False
except AttributeError:
    ret = True

if ret == True:
    print('Teste 5 - Acesso a atributo inexistente está OK.')
    sucesso += 1
else:
    print('Teste 5 - Acesso a atributo inexistente NÃO está OK.')
    falha += 1
    
# Listando os veículos no estacionamento.
if estacionamento.listarVeiculos() == False:
    print('Teste 6 - Listagem de veículos está OK.')
    sucesso += 1
else:
    print('Teste 6 - Listagem de veículos NÃO está OK.')
    falha += 1
    
# Adicionando veiculo.
if estacionamento.adicionarVeiculo('OST8989', onibus1) == True:
    print('Teste 7 - Adiçao de veículo está OK.')
    sucesso += 1
else:
    print('Teste 7 - Adiçao de veículo NÃO está OK.')
    falha += 1

# Verificando a ocupação atual.
if estacionamento.getOcupaçãoAtual() == 1:
    print('Teste 8 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 8 - Ocupação atual NÃO está OK.')
    falha += 1

# Listando os veículos no estacionamento.
if estacionamento.listarVeiculos() == True:
    print('Teste 9 - Listagem de veículos estacionados está OK.')
    sucesso += 1
else:
    print('Teste 9 - Listagem de veículos estacionados NÃO está OK.')
    falha += 1
    
if estacionamento.adicionarVeiculo('OOK2034', moto1) == True:
    print('Teste 10 - Adiçao de veículo está OK.')
    sucesso += 1
else:
    print('Teste 10 - Adiçao de veículo NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if estacionamento.getOcupaçãoAtual() == 2:
    print('Teste 11 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 11 - Ocupação atual NÃO está OK.')
    falha += 1

# Adicionando veiculo.
if estacionamento.adicionarVeiculo('HDT6542', carro1) == True:
    print('Teste 12 - Adiçao de veículo está OK.')
    sucesso += 1
else:
    print('Teste 12 - Adiçao de veículo NÃO está OK.')
    falha += 1

# Verificando a ocupação atual.
if estacionamento.getOcupaçãoAtual() == 3:
    print('Teste 13 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 13 - Ocupação atual NÃO está OK.')
    falha += 1

# Adicionando veiculo.
if estacionamento.adicionarVeiculo('HOT4356', carro2) == False:
    print('Teste 14 - Adiçao de veículo está OK.')
    sucesso += 1
else:
    print('Teste 14 - Adiçao de veículo NÃO está OK.')
    falha += 1
    
# Listando os veículos no estacionamento.
if estacionamento.listarVeiculos() == True:
    print('Teste 15 - Listagem de veículos estacionados está OK.')
    sucesso += 1
else:
    print('Teste 15 - Listagem de veículos estacionados NÃO está OK.')
    falha += 1

# Removendo veiculo.
if estacionamento.removerVeiculo('HOT4356') == False:
    print('Teste 16 - Remoção de veículo está OK.')
    sucesso += 1
else:
    print('Teste 16 - Remoção de veículo NÃO está OK.')
    falha += 1
    
# Removendo veiculo.
if estacionamento.removerVeiculo('HOT4356') == False:
    print('Teste 17 - Remoção de veículo está OK.')
    sucesso += 1
else:
    print('Teste 17 - Remoção de veículo NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if estacionamento.getOcupaçãoAtual() == 3:
    print('Teste 18 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 18 - Ocupação atual NÃO está OK.')
    falha += 1
    
# Removendo veiculo.
if estacionamento.removerVeiculo('OOK2034') == True:
    print('Teste 19 - Remoção de veículo está OK.')
    sucesso += 1
else:
    print('Teste 19 - Remoção de veículo NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if estacionamento.getOcupaçãoAtual() == 2:
    print('Teste 20 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 20 - Ocupação atual NÃO está OK.')
    falha += 1
    
# Removendo veiculo.
if estacionamento.removerVeiculo('OST8989') == True:
    print('Teste 21 - Remoção de veículo está OK.')
    sucesso += 1
else:
    print('Teste 21 - Remoção de veículo NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if estacionamento.getOcupaçãoAtual() == 1:
    print('Teste 22 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 22 - Ocupação atual NÃO está OK.')
    falha += 1

# Removendo veiculo.
if estacionamento.removerVeiculo('HDT6542') == True:
    print('Teste 23 - Remoção de veículo está OK.')
    sucesso += 1
else:
    print('Teste 23 - Remoção de veículo NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if estacionamento.getOcupaçãoAtual() == 0:
    print('Teste 24 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 24 - Ocupação atual NÃO está OK.')
    falha += 1

# Removendo veiculo.
if estacionamento.removerVeiculo('FGT6754') == False:
    print('Teste 25 - Remoção de veículo está OK.')
    sucesso += 1
else:
    print('Teste 25 - Remoção de veículo NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if estacionamento.getOcupaçãoAtual() == 0:
    print('Teste 26 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 26 - Ocupação atual NÃO está OK.')
    falha += 1
    
# Listando os veículos no estacionamento.
if estacionamento.listarVeiculos() == False:
    print('Teste 27 - Listagem de veículos estacionados está OK.')
    sucesso += 1
else:
    print('Teste 27 - Listagem de veículos estacionados NÃO está OK.')
    falha += 1
    
# Verificando as placas dos veiculos.
valores_esperados = ['OOK2034', 'OST8989', 'HDT6542', 'HOT4356']
veiculos = [moto1, onibus1, carro1, carro2]

ret = True
for i in range(0, len(veiculos)):
    if veiculos[i].getPlaca() != valores_esperados[i]:
        ret = False
        break

if ret == True:
    print('Teste 28 - As placas dos veículos está OK.')
    sucesso += 1
else:
    print('Teste 28 - As placas dos veículos NÃO está OK.')
    falha += 1

print('\n\n******* Resultado final dos testes *******')
if sucesso == 28 and falha == 0:
    print('Sucessos: %d - Falhas: %d' % (sucesso, falha))
    print('Todos os testes foram bem sucedidos, sua implementação está OK!')
else:
    print('Sucessos: %d - Falhas: %d' % (sucesso, falha))
    print('Alguns testes falharam, sua implementação NÃO está OK... verifique seu código.')
print('******************************************')
# Out:
# Teste 1 - Kilometragem está OK.
# Teste 2 - Ocupação inicial está OK.
# Teste 3 - Acesso a atributo privado está OK.
# Teste 4 - Acesso a atributo inexistente está OK.
# Teste 5 - Acesso a atributo inexistente está OK.
# Teste 6 - Listagem de veículos está OK.
# Teste 7 - Adiçao de veículo está OK.
# Teste 8 - Ocupação atual está OK.
# --------------------------
# Marca: Mercedes-Benz
# Modelo: Paradiso G7 1200
# Cor: branco
# Placa: OST8989
# Kilometragem: 200010.99
# --------------------------
# Teste 9 - Listagem de veículos estacionados está OK.
# Teste 10 - Adiçao de veículo está OK.
# Teste 11 - Ocupação atual está OK.
# Teste 12 - Adiçao de veículo está OK.
# Teste 13 - Ocupação atual está OK.
# Teste 14 - Adiçao de veículo está OK.
# --------------------------
# Marca: Mercedes-Benz
# Modelo: Paradiso G7 1200
# Cor: branco
# Placa: OST8989
# Kilometragem: 200010.99
# --------------------------
# --------------------------
# Marca: Honda
# Modelo: CB650R
# Cor: vermelho
# ...
