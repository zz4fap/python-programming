# %% [markdown]
# # Prova #2 C126-L1 (1S2021)
#
# ### Instruções
#
# 1. Para cada um dos exercícios a seguir, faça o seguinte:
#     * Adicione comentários ao seu código explicando o que você fez.
#     * Caso o exercício involva a implementação de uma função:
#         + Coloque um comentário dizendo o que a função faz, use **docstrings**.
#         + Escolha nomes auto-explicativos para suas funções e parâmetros.
#
# 2. Quando você terminar a prova, vá ao menu do Jupyter ou Colab e selecione a opção para fazer download do notebook.
#     * Os notebooks tem extensão .ipynb.
#     * Este deve ser o arquivo que você irá entregar.
#     * No Jupyter vá até a opção **File** -> **Download as** -> **Notebook (.ipynb)**.
#     * No Colab vá até a opção **File** -> **Download .ipynb**.
#
# 3. Em seguida, faça a entrega do notebook da prova (ou seja, anexe o arquivo) na tarefa criada no MS Teams.
# 4. Atente-se ao prazo de entrega definido na tarefa do MS Teams.
# 5. **A prova deve ser resolvida individualmente**.
# 6. Todas as questões têm o mesmo peso.
# 7. Não se esqueça de colocar seu nome e número de matrícula nos campos abaixo.
# 8. Você pode consultar o material de aula.
# 9. A interpretação faz parte da prova.
# 10. Boa sorte!

# %% [markdown]
# **Nome**:
#
# **Matrícula**:

# %% [markdown]
# ## Exercícios

# %% [markdown]
# #### 1) Exercício sobre listas e dicionários.
#
# Escreva uma função chamada `imprimirMaioresPreços` que receba uma **tupla** contendo informações sobre preços de diversos produtos em diferentes datas e que retorne um **dicionário**, onde a **chave** de cada elemento é o nome (i.e., string) do produto e o **valor** associado é o **maior** preço que aquele produto já teve. Para testar a sua função, utilizaremos os valores abaixo como entrada. Veja que a tupla com as informações dos produtos já está disponibilizada no código de teste, portanto, apenas implemente a função e execute o código de teste.
#
# |    Data    |  Produto  | Preço |
# |:----------:|:---------:|:-----:|
# | 29/06/2017 |   cebola  |  2.19 |
# | 29/06/2017 |   batata  |  1.98 |
# | 29/06/2017 |   alface  |  1.88 |
# | 22/06/2017 | beterraba |  2.48 |
# | 22/06/2017 |   alface  |  2.00 |
# | 22/06/2017 |   cebola  |  2.03 |
# | 15/06/2017 | beterraba |  2.44 |
# | 15/06/2017 |   alface  |  1.75 |
# | 15/06/2017 |   batata  |  2.11 |
#
# **IMPORTANTE**
# + Sua função deve ser o mais genérica possível, ou seja, ela deve funcionar até para podutos que não estão na tabela acima.

# %%
# Implemente aqui o código da função.

# %% [markdown]
# Teste sua implementação com o código abaixo, o qual deve resultar em todos os testes tendo o status OK.
#
# **NÃO ALTERE O CÓDIGO ABAIXO EM HIPÓTESE ALGUMA.**

# %%
lista = ('29/06/2020', 'cebola', 2.19, '29/06/2020', 'batata', 1.98, '29/06/2020', 'alface', 1.88, '22/06/2020', 'beterraba', 2.48, '22/06/2020', 'alface', 2.00, '22/06/2020', 'cebola', 2.03, '15/06/2020', 'beterraba', 2.44, '15/06/2020', 'alface', 1.75, '15/06/2020', 'batata', 2.11)

ret = 0

maioresPreços = imprimirMaioresPreços(lista)
if(maioresPreços == {'cebola': 2.19, 'batata': 2.11, 'alface': 2.0, 'beterraba': 2.48}):
    ret += 1

lista = ('01/01/2021', 'morango', 3.21, '29/06/2020', 'cebola', 2.19, '29/06/2020', 'batata', 1.98, '29/06/2020', 'alface', 1.88, '22/06/2020', 'beterraba', 2.48, '22/06/2020', 'alface', 2.00, '22/06/2020', 'cebola', 2.03, '15/06/2020', 'beterraba', 2.44, '15/06/2020', 'alface', 1.75, '15/06/2020', 'batata', 2.11)

maioresPreços = imprimirMaioresPreços(lista)
if(maioresPreços == {'morango': 3.21, 'cebola': 2.19, 'batata': 2.11, 'alface': 2.0, 'beterraba': 2.48}):
    ret += 1
    
if(ret == 2):
    print('Sua implementação está OK!')
else:
    print('Sua implementação não está correta...')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-93200b180097> in <module>
#       3 ret = 0
#       4
# ----> 5 maioresPreços = imprimirMaioresPreços(lista)
#       6 if(maioresPreços == {'cebola': 2.19, 'batata': 2.11, 'alface': 2.0, 'beterraba': 2.48}):
#       7     ret += 1
#
# NameError: name 'imprimirMaioresPreços' is not defined

# %% [markdown]
# #### 2) Exercício sobre POO.
#
# Implemente a classe mostrada no diagrama UML mostrado abaixo. Siga examente as especificações mostradas na figura, ou seja, nomes dos atributos, nomes dos métodos, número de parâmetros dos métodos, encapsulamentos dos membros da classe. etc.
#
# Seguem algumas instruções para a implementação da classe:
# 1. Os métodos **públicos** `getMarca()`, `getModelo()`, `getPlaca()` e `getCor()` devem retornar os valores dos respectivos atributos.
# 2. O método **privado** `injetarCombustível()` deve retornar a string `injetando combustível`.
# 3. O método **privado** `acionarPastilhaDeFreio()` deve retornar a string `acionando pastilha de freio`.
# 4. O método **público** `acelerar()` deve chamar o método `injetarCombustível()` e em seguida retornar a string `Acelerando`.
# 5. O método **público** `frear()` deve chamar o método `acionarPastilhaDeFreio()` e em seguida retornar a string `Freando`.
# 6. O método **público** `imprimirInfo()` deve **imprimir** as informações do veículo, ou seja, sua marca, modelo, cor, placa e kilometragem.
# 7. O método **público** `setPlaca()` deve alterar o atributo **privado** `placa` com uma nova placa passada como agumento de entrada para o método.
#
# **OBS.**: Prestem bastante atenção ao tipo de acesso (i.e., privado, protegido ou público) de cada **atributo** e **método** da classe.
#
# <img src="../figures/veiculoProva2.png" width="300" height="300">

# %%
# Implemente aqui a classe.

# %% [markdown]
# Teste sua implementação com o código abaixo, o qual deve resultar em todos os testes tendo o status OK.
#
# **NÃO ALTERE O CÓDIGO ABAIXO EM HIPÓTESE ALGUMA.**

# %%
carro = Veículo('VW', 'fusca', 'preto', 'FGT-3056', 100000)
ret = 0
if(carro.getMarca()=='VW'):
    ret += 1
if(carro.getModelo()=='fusca'):
    ret += 1
if(carro.getPlaca()=='FGT-3056'):
    ret += 1
if(carro.getCor()=='preto'):
    ret += 1
if(carro.kilometragem==100000):
    ret += 1
if(carro._cor=='preto'):
    ret += 1
try:
    carro.__marca
except AttributeError:
    ret += 1
try:
    carro.__modelo
except AttributeError:
    ret += 1
try:
    carro.__placa
except AttributeError:
    ret += 1
try: 
    carro.__injetarCombustível()
except AttributeError:
    ret += 1
try:
    carro.__acionarPastilhaDeFreio()
except AttributeError:
    ret += 1
carro.setPlaca('FST-6789')
if(carro.getPlaca()=='FST-6789'):
    ret += 1
if(carro.imprimirInfo()==None):
    ret += 1
if(carro.frear()=='Freando'):
    ret += 1
if(carro.acelerar()=='Acelerando'):
    ret += 1
if(ret==15):
    print('\nSua implementação está OK!')
else:
    print('\nSua implementação NÃO está correta...')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-893a1fbac3b0> in <module>
# ----> 1 carro = Veículo('VW', 'fusca', 'preto', 'FGT-3056', 100000)
#       2 ret = 0
#       3 if(carro.getMarca()=='VW'):
#       4     ret += 1
#       5 if(carro.getModelo()=='fusca'):
#
# NameError: name 'Veículo' is not defined

# %% [markdown]
# #### 3)  Exercício sobre arquivos alfanuméricos.
#
# Escreva uma função chamada `calcularProduto()` que receba como parâmetro de entrada o nome de um arquivo. Esta função deve ler o arquivo, o qual será um arquivo contendo ao menos 1 número real por linha e, para cada linha, a função deve calcular o produto destes valores e adicioná-lo a uma lista. Desta forma, cada elemento da lista será o produto de cada uma das linhas do arquivo.
#
# **DICAS**
# 1. Após ler uma linha do arquivo, use o método `split()` da classe string para obter uma lista onde cada elemento é um dos valores da linha.
# 2. Use a função embutida `float()` para converter a string representando cada um dos valores da lista em um número em ponto flutuante.

# %%
# Implemente aqui o código da função.

# %% [markdown]
# Teste sua implementação com o código abaixo, o qual deve resultar em todos os testes tendo o status OK.
#
# **NÃO ALTERE O CÓDIGO ABAIXO EM HIPÓTESE ALGUMA.**

# %%
with open('numeros.txt', 'w') as f:
    f.write('5 4 3 2 1\n')
    f.write('4 4\n')
    f.write('2.7\n')
    f.write('3.14 2.1 1.7')

ret = 0
if(calcularProduto('numeros.txt') == [120.0, 16.0, 2.7, 11.2098]):
    ret += 1
    
if(ret == 1):
    print('Sua implementação está OK!')
else:
    print('Sua implementação não está correta...')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-63d79f72dd34> in <module>
#       6
#       7 ret = 0
# ----> 8 if(calcularProduto('numeros.txt') == [120.0, 16.0, 2.7, 11.2098]):
#       9     ret += 1
#      10
#
# NameError: name 'calcularProduto' is not defined

# %% [markdown]
# #### 4) Exercício sobre programação orientada a objetos e manipulação de arquivos.
#
# Neste exercício você deve implementar a classe do diagrama abaixo e seguir as dicas para sua implementação.
#
# **IMPORTANTE**: Neste exercício você deverá utilizar um **arquivo CSV** para armazenar as informações sobre os alunos de uma Universidade.
#
# <img src="../figures/universidadeProva2.png" width="300" height="300">
#
# Seguem algumas dicas para a implementação da classe:
#
# 1. Prestem bastante atenção ao tipo de acesso (i.e., privado, protegido ou público) de cada **atributo** e **método** da classe.
# 2. Usem a instrução `with` para trabalhar com os arquivos. Lembrem-se que a instrução `with` fecha o arquivo automaticamente.
# 3. O construtor da classe `Universidade` deve criar um **arquivo CSV** chamado `universidade.csv` com as seguintes colunas: `Matrícula`, `Nome`, `Sexo`, `Idade` e `Telefone`. Este arquivo será usado para armazenar as informações de cada aluno da universidade.
# 4. O atributo `nome` da classe `Universidade` é o nome da universidade.
# 5. O método `adicionarAluno(aluno)` da classe `Universidade` deve adicionar um novo aluno ao arquivo `universidade.csv` apenas se a `capacidade` da universidade não tiver sido atingida e a matrícula do aluno não estiver presente no arquivo, nesse caso, o método deve retornar `True`. Caso contrário, se a universidade estiver cheia ou a matrícula do aluno já estiver presente no arquivo, o método deve retornar `False`.
# 6. O parâmetro de entrada `aluno` do método `adicionarAluno` é uma lista com valores para os seguintes elementos: `matrícula`, `nome`, `sexo`, `idade` e `telefone` de cada aluno a ser adicionado ao arquivo.
# 7. O método `removerAluno(matrícula)` da classe `Universidade` deve remover um aluno do arquivo `universidade.csv` e retornar `True` após a remoção bem sucedida do aluno. Caso contrário, se o aluno não existir no arquivo, então o método deve retornar `False`.
#
#     **DICAS**:
#     + Antes de remover o aluno, verifique se ele está presente no arquivo `universidade.csv`.
#     + Uma forma simples de remover um aluno do arquivo é criar uma **lista** onde cada um dos elementos é uma das linhas do arquivo exceto aquela do aluno a ser removido, abrir o arquivo `universidade.csv` com o modo de operação `w` para que todas as informações anteriores sejam apagadas e, em seguida, escrever cada uma das linhas da lista no arquivo.
#
# 8. O método `listarAlunos()` da classe `Universidade` deve imprimir as informações de todos os alunos da universidade. Este método deve retornar `True` caso a ocupação atual da universidade seja maior do que 0. Caso contrário, se a universidade estiver vazia e nenhuma informação for impressa, o método deve retornar `False`.
# 9. O método `getOcupaçãoAtual()` da classe `Universidade` deve retornar o número de alunos da universidade.
# 10. O método `listarAluno(matrícula)` da classe `Universidade` deve imprimir as informações do aluno com a `matrícula` passada como argumento de entrada para o método. Este método deve retornar `True` caso a ocupação atual da universidade seja maior do que 0 e se o aluno estiver presente no arquivo `universidade.csv`. Caso contrário, se a universidade estiver vazia ou o aluno não estiver presente no arquivo, então, nenhuma informação deve ser impressa e o método deve retornar `False`.

# %%
# Implemente o código do exercício aqui.

# %% [markdown]
# Teste sua implementação com o código abaixo, o qual deve resultar em todos os testes tendo o status OK.
#
# **NÃO ALTERE O CÓDIGO ABAIXO EM HIPÓTESE ALGUMA.**

# %%
import csv

# Definindo alguns alunos.
aluno1 = ['101', 'João da Silva', 'Masculino', '19', '3471-9800']
aluno2 = ['678', 'Thaís Elegário', 'Feminino', '20', '9876-7098']
aluno3 = ['123', 'José Benedito', 'Masculino', '34', '3422-1235']
aluno4 = ['456', 'Ana Vilasboas', 'Feminino', '21', '3261-1037']

# Contador de casos de sucesso.
sucesso = 0 
falha = 0

# Instanciando uma universidade.
uni = Universidade('Central', 3)

if uni.getOcupaçãoAtual() == 0:
    print('Teste 1 - Ocupação inicial está OK.')
    sucesso += 1
else:
    print('Teste 1 - Ocupação inicial NÃO está OK.')
    falha += 1
    
# Listando os alunos da universidade.
if uni.listarAlunos() == False:
    print('Teste 2 - Listagem de alunos está OK.')
    sucesso += 1
else:
    print('Teste 2 - Listagem de alunos NÃO está OK.')
    falha += 1
    
# Adicionando um aluno.
if uni.adicionarAluno(aluno1) == True:
    print('Teste 3 - Adiçao de aluno está OK.')
    sucesso += 1
else:
    print('Teste 3 - Adiçao de aluno NÃO está OK.')
    falha += 1

# Verificando a ocupação atual.
if uni.getOcupaçãoAtual() == 1:
    print('Teste 4 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 4 - Ocupação atual NÃO está OK.')
    falha += 1

# Listando os alunos da universidade.
if uni.listarAlunos() == True:
    print('Teste 5 - Listagem de alunos está OK.')
    sucesso += 1
else:
    print('Teste 5 - Listagem de alunos NÃO está OK.')
    falha += 1
    
if uni.adicionarAluno(aluno2) == True:
    print('Teste 6 - Adiçao de aluno está OK.')
    sucesso += 1
else:
    print('Teste 6 - Adiçao de aluno NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if uni.getOcupaçãoAtual() == 2:
    print('Teste 7 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 7 - Ocupação atual NÃO está OK.')
    falha += 1

# Adicionando um aluno.
if uni.adicionarAluno(aluno3) == True:
    print('Teste 8 - Adiçao de aluno está OK.')
    sucesso += 1
else:
    print('Teste 8 - Adiçao de aluno NÃO está OK.')
    falha += 1

# Verificando a ocupação atual.
if uni.getOcupaçãoAtual() == 3:
    print('Teste 9 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 9 - Ocupação atual NÃO está OK.')
    falha += 1

# Adicionando um aluno.
if uni.adicionarAluno(aluno4) == False:
    print('Teste 10 - Adiçao de aluno está OK.')
    sucesso += 1
else:
    print('Teste 10 - Adiçao de aluno NÃO está OK.')
    falha += 1
    
# Listando os alunos.
if uni.listarAlunos() == True:
    print('Teste 11 - Listagem de alunos está OK.')
    sucesso += 1
else:
    print('Teste 11 - Listagem de alunos NÃO está OK.')
    falha += 1

# Removendo um aluno.
if uni.removerAluno('456') == False:
    print('Teste 12 - Remoção de aluno está OK.')
    sucesso += 1
else:
    print('Teste 12 - Remoção de aluno NÃO está OK.')
    falha += 1
    
# Removendo um aluno.
if uni.removerAluno('789') == False:
    print('Teste 13 - Remoção de aluno está OK.')
    sucesso += 1
else:
    print('Teste 13 - Remoção de aluno NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if uni.getOcupaçãoAtual() == 3:
    print('Teste 14 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 14 - Ocupação atual NÃO está OK.')
    falha += 1
    
# Removendo um aluno.
if uni.removerAluno('101') == True:
    print('Teste 15 - Remoção de aluno está OK.')
    sucesso += 1
else:
    print('Teste 15 - Remoção de aluno NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if uni.getOcupaçãoAtual() == 2:
    print('Teste 16 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 16 - Ocupação atual NÃO está OK.')
    falha += 1
    
# Removendo um aluno.
if uni.removerAluno('678') == True:
    print('Teste 17 - Remoção de aluno está OK.')
    sucesso += 1
else:
    print('Teste 17 - Remoção de aluno NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if uni.getOcupaçãoAtual() == 1:
    print('Teste 18 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 18 - Ocupação atual NÃO está OK.')
    falha += 1

# Removendo um aluno.
if uni.removerAluno('123') == True:
    print('Teste 19 - Remoção de aluno está OK.')
    sucesso += 1
else:
    print('Teste 19 - Remoção de aluno NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if uni.getOcupaçãoAtual() == 0:
    print('Teste 20 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 20 - Ocupação atual NÃO está OK.')
    falha += 1

# Removendo um aluno.
if uni.removerAluno('120') == False:
    print('Teste 21 - Remoção de aluno está OK.')
    sucesso += 1
else:
    print('Teste 21 - Remoção de aluno NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if uni.getOcupaçãoAtual() == 0:
    print('Teste 22 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 22 - Ocupação atual NÃO está OK.')
    falha += 1
    
# Listando os alunos.
if uni.listarAlunos() == False:
    print('Teste 23 - Listagem de alunos está OK.')
    sucesso += 1
else:
    print('Teste 23 - Listagem de alunos NÃO está OK.')
    falha += 1
    
# Adicionando um aluno.
if uni.adicionarAluno(aluno1) == True:
    print('Teste 24 - Adiçao de aluno está OK.')
    sucesso += 1
else:
    print('Teste 24 - Adiçao de aluno NÃO está OK.')
    falha += 1
    
# Adicionando um aluno.
if uni.adicionarAluno(aluno1) == False:
    print('Teste 25 - Adiçao de aluno está OK.')
    sucesso += 1
else:
    print('Teste 25 - Adiçao de aluno NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if uni.getOcupaçãoAtual() == 1:
    print('Teste 26 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 26 - Ocupação atual NÃO está OK.')
    falha += 1
    
# Busca por aluno específico.
if uni.listarAluno('333') == False:
    print('Teste 27 - Busca por aluno específico está OK.')
    sucesso += 1
else:
    print('Teste 27 - Busca por aluno específico NÃO está OK.')
    falha += 1
    
# Busca por aluno específico.
if uni.listarAluno('101') == True:
    print('Teste 28 - Busca por aluno específico está OK.')
    sucesso += 1
else:
    print('Teste 28 - Busca por aluno específico NÃO está OK.')
    falha += 1
    
# Removendo aluno.
if uni.removerAluno('101') == True:
    print('Teste 29 - Remoção de aluno está OK.')
    sucesso += 1
else:
    print('Teste 29 - Remoção de aluno NÃO está OK.')
    falha += 1
    
# Verificando a ocupação atual.
if uni.getOcupaçãoAtual() == 0:
    print('Teste 30 - Ocupação atual está OK.')
    sucesso += 1
else:
    print('Teste 30 - Ocupação atual NÃO está OK.')
    falha += 1

print('\n\n******* Resultado final dos testes *******')
if sucesso == 30 and falha == 0:
    print('Sucessos: %d - Falhas: %d' % (sucesso, falha))
    print('Todos os testes foram bem sucedidos, sua implementação está OK!')
else:
    print('Sucessos: %d - Falhas: %d' % (sucesso, falha))
    print('Alguns testes falharam, sua implementação NÃO está OK... verifique seu código.')
print('******************************************')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f59b2cedf2a0> in <module>
#      12
#      13 # Instanciando uma universidade.
# ---> 14 uni = Universidade('Central', 3)
#      15
#      16 if uni.getOcupaçãoAtual() == 0:
#
# NameError: name 'Universidade' is not defined
